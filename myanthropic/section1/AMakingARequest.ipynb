# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Load environment variables
from dotenv import load_dotenv
load_dotenv()
# Create an API client
from anthropic import Anthropic
client = Anthropic()
# What are model available? and which one to use?
# https://platform.claude.com/docs/en/about-claude/models/overview
# I choose Claude Haiku 4.5 because it is less expensive.
model = "claude-haiku-4-5"
# Make an API call

# %% [markdown]
# ![title](../img/create-message.png)

# %%
response = client.messages.create(
    model=model,
    max_tokens=300,
    messages=[
        {
            "role": "user",
            "content": "What is the meaning of life?"
        }
    ]
)
print(response.content[0].text)
# Out:
# That's one of humanity's oldest questions, and there's no single answer—partly because "meaning" itself is personal.
#
# A few frameworks people find helpful:
#
# **Purpose-driven**: meaning comes from working toward something you care about—relationships, creativity, helping others, mastery, or contributing to causes larger than yourself.
#
# **Experiential**: meaning emerges from connection, growth, beauty, laughter, or simply being present to life as it unfolds.
#
# **Philosophical/existential**: some argue we create meaning through our choices and how we respond to life's challenges, rather than discovering pre-existing meaning.
#
# **Spiritual/religious**: many find meaning in transcendent frameworks—faith, service, or alignment with deeper truths.
#
# **Modest view**: maybe there's no cosmic meaning, but that frees us to decide what matters to *us* personally.
#
# What often seems to resonate across these is something like: **meaning emerges when you're engaged with what matters to you, connected to others, or growing in some way.**
#
# What draws you to this question right now? Are you wrestling with something specific, or more philosophically curious?
