# %% [markdown]
# Claude doesn't store any of your conversation history. Each request you make is completely independent, with no memory of previous exchanges.
# This means if you want to have a multi-turn conversation where Claude remembers context from earlier messages, you need to handle the conversation state yourself.
#
# Let's say you ask Claude "What is quantum computing?" and get a good response. Then you follow up with "Write another sentence" - Claude has no idea what you're referring to. It will write a sentence about something completely random because it has no memory of the quantum computing discussion.
#
# ![title](../img/multiConversation.png)

# %%
from dotenv import load_dotenv
load_dotenv()
from anthropic import Anthropic
client = Anthropic()


model = "claude-haiku-4-5"

response = client.messages.create(
    model=model,
    max_tokens=300,
    messages=[
        {
            "role": "user",
            "content": "What is the LLM, explain in one line."
        }
    ]
)
print(response.content[0].text)

response = client.messages.create(
    model=model,
    max_tokens=300,
    messages=[
        {
            "role": "user",
            "content": "Generate anather line"
        }
    ]
)
print(response.content[0].text)
# Out:
# # LLM (Large Language Model)
#
# A Large Language Model is an artificial intelligence system trained on vast amounts of text data to understand and generate human language by predicting sequences of words.
# I'd be happy to generate another line, but I need more context! Could you clarify:
#
# 1. **What type of line?** (poetry, lyrics, dialogue, code, etc.)
# 2. **What was the previous line?** (so I can match the style/theme)
# 3. **What's the context or topic?**
#
# Please share more details and I'll create something for you!
